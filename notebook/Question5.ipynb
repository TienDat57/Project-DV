# %% [markdown]
# ### <center>📜 **<font color="cyan">Question 5:</font> Is it true that the more houses in the area, the higher the price?** </center>

# %% [markdown]
# #### 📙**Import the necessary libraries**

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/processed/VN_housing_dataset.csv')
df.drop(columns=['date','address'], inplace=True)
df
# Out:
#                 district              town             house_type  paper_type
# 0          Quận Cầu Giấy   Phường Nghĩa Đô           Nhà ngõ, hẻm    Đã có sổ  \
# 1        Quận Thanh Xuân  Phường Kim Giang  Nhà mặt phố, mặt tiền  Chưa có sổ
# 2      Quận Hai Bà Trưng  Phường Minh Khai           Nhà ngõ, hẻm    Đã có sổ
# 3            Quận Tây Hồ  Phường Thụy Khuê           Nhà ngõ, hẻm    Đã có sổ
# 4        Quận Thanh Xuân  Phường Kim Giang           Nhà ngõ, hẻm  Chưa có sổ
# ...                  ...               ...                    ...         ...
# 81393   Quận Nam Từ Liêm  Phường Mỹ Đình 1        Nhà phố liền kề    Đã có sổ
# 81394   Quận Bắc Từ Liêm  Phường Phúc Diễn        Nhà phố liền kề  Chưa có sổ
# 81395      Quận Cầu Giấy   Phường Quan Hoa  Nhà mặt phố, mặt tiền  Chưa có sổ
# 81396      Quận Cầu Giấy   Phường Quan Hoa  Nhà mặt phố, mặt tiền    Đã có sổ
# 81397      Quận Cầu Giấy   Phường Quan Hoa           Nhà ngõ, hẻm    Đã có sổ
#
#        num_floors  num_rooms  squares  price_per_m2     price
# 0               4          5       46         86.96   4000.16
# 1               0          3       37        116.22   4300.14
# 2               4          4       40         65.00   2600.00
# 3               0          6       51        100.00   5100.00
# 4               0          4       36         86.11   3099.96
# ...           ...        ...      ...           ...       ...
# 81393           0          3       38         76.32   2900.16
# 81394           0          3       38         81.58   3100.04
# 81395           0          3       50        292.00  14600.00
# 81396           0          4       41        341.46  13999.86
# 81397           0          4       60        101.67   6100.20
#
# [81398 rows x 9 columns]

# %%
grouped = df.groupby('district').agg({'price': ['mean', 'min', 'max', 'count'], }).reset_index()
grouped
# Out:
#              district         price
#                                mean        min        max  count
# 0         Huyện Ba Vì   9648.500000  1249.5000   24696.00      3
# 1     Huyện Chương Mỹ   2616.659444   500.0000    7400.00     18
# 2       Huyện Gia Lâm   6160.106929   255.7500   65000.00    267
# 3      Huyện Hoài Đức   3565.033521   175.0000   69856.00    443
# 4       Huyện Mê Linh   5110.960000   680.0000   19950.00     11
# 5        Huyện Mỹ Đức   2899.700000  2899.7000    2899.70      1
# 6     Huyện Phú Xuyên   8888.660000  8888.6600    8888.66      1
# 7      Huyện Phúc Thọ   2312.555000  1625.0000    3000.11      2
# 8      Huyện Quốc Oai  10944.006000   600.0000  120000.42     20
# 9       Huyện Sóc Sơn   2301.836410   188.8000    8099.85     39
# 10    Huyện Thanh Oai   1624.216275   599.9400    3900.05     51
# 11    Huyện Thanh Trì   3099.349167    61.9500   68999.93   1188
# 12   Huyện Thường Tín   7089.721875   794.8800   48048.00     16
# 13   Huyện Thạch Thất   3769.385556  1150.0000    8000.00      9
# 14   Huyện Đan Phượng   4791.813810   920.0000   26000.00     21
# 15     Huyện Đông Anh   4242.731868   210.0000   39984.00     91
# 16       Quận Ba Đình   6474.747422     4.5000  240000.00   4650
# 17   Quận Bắc Từ Liêm   4554.995580   100.2000  160000.00   1518
# 18      Quận Cầu Giấy   6625.523226     3.6000  270001.14   6542
# 19  Quận Hai Bà Trưng   4674.338423     2.2000  245998.50  10369
# 20     Quận Hoàn Kiếm  18150.244430    31.0000  351997.80    526
# 21     Quận Hoàng Mai   3691.774479    33.3333   80000.00  11036
# 22       Quận Hà Đông   4099.073946     9.8000   90000.72   7755
# 23     Quận Long Biên   4582.401446     5.3000  100000.00   4180
# 24   Quận Nam Từ Liêm   5017.680244     3.0500  119875.00   3151
# 25    Quận Thanh Xuân   4666.626986     1.5500  134940.00  12744
# 26        Quận Tây Hồ   8602.797236    31.0000  236998.74   2920
# 27       Quận Đống Đa   5438.428017     2.5000  135000.00  13810
# 28     Thị xã Sơn Tây   5769.645625   550.5600   37912.00     16

# %%
grouped.columns = ['district', 'mean_price', 'min_price', 'max_price', 'count']

# %%
grouped.sort_values("count", ascending=True).plot.barh(x='district', y='count', figsize=(20, 10))
# Out:
# <AxesSubplot:ylabel='district'>

# %%
grouped.sort_values("count", ascending=True).plot.barh(x='district', y='mean_price', figsize=(20, 10))
# Out:
# <AxesSubplot:ylabel='district'>

# %% [markdown]
# #### Conclusion
# - As can be seen, The mean of the price fluctuate without any pattern when we sort by number of house. In other words, the price of the house is uncertain and not depend on whether it is a dense house area or not.
